# %% [markdown]
# <a href="https://colab.research.google.com/github/Only-Eni/Google-Developers-Group-Campus/blob/main/GDG_AI_DAY2_PANDAS_NUMPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 1

# %%
#Removing the Duplicates
df.drop_duplicates(inplace=True)

#Printing the Successful Outputs
print("Duplicates removed Successfully!")
# Out:
# Duplicates removed Successfully!

# %% [markdown]
# ## Duplicate Handling
#
# The dataset contained 1 duplicate rows.
# These duplicates were removed to prevent biased analysis and inflated results.

# %%
df['column_name'] = df['column_name'].fillna(df['column_name'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-286341606.py in <cell line: 0>()
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
