# %% [markdown]
# <a href="https://colab.research.google.com/github/Only-Eni/Google-Developers-Group-Campus/blob/main/GDG_AI_DAY7_PANDAS_NUMPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("UNDERSTANDING DATA CONCEPTS")
# Out:
# UNDERSTANDING DATA CONCEPTS

# %% [markdown]
# #UNDERSTANDING DATA CONCEPTS
#
#
# - In this last week, alot challenged me while learning n growing as a ML/AI Data analyst. As someone who just got introduced to writing codes in pandas-numpy to clean messy datas, remove duplicate values and derive insights from data.

# %% [markdown]
# ##Things i learned throughout the last 7 days of this challenge
#
# * how to load in a dataset, check for missing values and duplicates
# * how to deduce the mean and std using numpy
# * how to make use of matplotlib and seaborn to visualize insights from the data
# * how to make arrays and ways they can be reshaped

# %% [markdown]
# ##Things that challenged  me
#
#
# * using numpy to derive insights....pandas was quite easy cleaning data
# * the use of matplotlib to visualize insights tested my patience and i almost thought to just give up the challlenge

# %% [markdown]
# ##Where i will improve?
#
#
# * definately with writing codes first, knowing the right codes to make use of while working with numpy and pandas is something i should upskill on
# * understanding the structure and aim of a dataset before using matplotlib, to avoid just visuals with poor insights from data
